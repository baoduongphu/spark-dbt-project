# %%
df = spark.read \
    .format("delta") \
    .load("/path/to/delta/table")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df = spark.read \
#       2     .format("delta") \
#       3     .load("/path/to/delta/table")
#
# NameError: name 'spark' is not defined
